# %% [markdown]
# # Task 3-Business Analysis
# In this task we have to find out the weak areas where can work to make more profit

# %% [markdown]
# # Author: Ritu Raj

# %%
#Packages for data handling
import pandas as pd
import numpy as np

#Packages for data visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading of data

# %%
data=pd.read_csv('SampleSuperstore.csv')

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 702.8+ KB

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %% [markdown]
# ## Data Visualisation

# %%
plt.figure(figsize=(20,10))
sns.countplot('Ship Mode',data=df)
plt.title('Counts by Ship Mode',fontsize=20)
plt.show()
# Out:
# C:\Users\rajri\.conda\envs\data_science\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
category_profit=df.groupby('Category')['Profit'].sum()
category_profit
# Out:
# Category
# Furniture           18451.2728
# Office Supplies    122490.8008
# Technology         145454.9481
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=category_profit.index,y=category_profit.values)
plt.title('Category wise profit')
plt.show()

# %%
sns.jointplot(x='Ship Mode',y='Profit',data=df)

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.countplot('Segment',data=df)
plt.title('Counts of Segment',fontsize=20)
plt.show()
# Out:
# C:\Users\rajri\.conda\envs\data_science\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(20,10))
sns.jointplot(x='Segment',y='Profit',kind='scatter',data=df)
plt.show()

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
sns.countplot('Category',data=df)
# Out:
# C:\Users\rajri\.conda\envs\data_science\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
sns.jointplot(x='Category',y='Profit',data=df)

# %%
sns.jointplot(x='Sales',y='Profit',data=df)

# %%
df['City'].value_counts()[:10]
# Out:
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
# Houston          377
# Chicago          314
# Columbus         222
# San Diego        170
# Springfield      163
# Name: City, dtype: int64

# %%
city_profit=df.groupby('State')['Profit'].sum()
city_profit
# Out:
# State
# Alabama                  5786.8253
# Arizona                 -3427.9246
# Arkansas                 4008.6871
# California              76381.3871
# Colorado                -6527.8579
# Connecticut              3511.4918
# Delaware                 9977.3748
# District of Columbia     1059.5893
# Florida                 -3399.3017
# Georgia                 16250.0433
# Idaho                     826.7231
# Illinois               -12607.8870
# Indiana                 18382.9363
# Iowa                     1183.8119
# Kansas                    836.4435
# Kentucky                11199.6966
# Louisiana                2196.1023
# Maine                     454.4862
# Maryland                 7031.1788
# Massachusetts            6785.5016
# Michigan                24463.1876
# Minnesota               10823.1874
# Mississippi              3172.9762
# Missouri                 6436.2105
# Montana                  1833.3285
# Nebraska                 2037.0942
# ...

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=city_profit.index,y=city_profit.values)
plt.title('City wise Profit',fontsize=20)
plt.xticks(rotation=90)
plt.show()

# %%
df['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
region_profit=df.groupby('Region')['Profit'].sum()
region_profit
# Out:
# Region
# Central     39706.3625
# East        91522.7800
# South       46749.4303
# West       108418.4489
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=region_profit.index,y=region_profit.values)
plt.title('Region wise profit',fontsize=20)
plt.show()

# %%
discount_profit=df.groupby('Discount')['Profit'].sum()
discount_profit
# Out:
# Discount
# 0.00    320987.6032
# 0.10      9029.1770
# 0.15      1418.9915
# 0.20     90337.3060
# 0.30    -10369.2774
# 0.32     -2391.1377
# 0.40    -23057.0504
# 0.45     -2493.1111
# 0.50    -20506.4281
# 0.60     -5944.6552
# 0.70    -40075.3569
# 0.80    -30539.0392
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=discount_profit.index,y=discount_profit.values)
plt.title('Discount per profit',fontsize=20)
plt.show()

# %%
sns.jointplot(x='Discount',y='Profit',data=df)

# %%
sns.catplot(x='Discount',y='Profit',data=df)

# %%
df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
sns.regplot(x=df['Sales'],y=df['Profit'],data=df)
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Profit'>

# %%
sns.regplot(x=df['Discount'],y=df['Profit'],data=df)
# Out:
# <AxesSubplot:xlabel='Discount', ylabel='Profit'>

# %%
df['State'].value_counts()[:10]
# Out:
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: State, dtype: int64

# %%
state_profit=df.groupby('State')['Profit'].sum()
state_profit
# Out:
# State
# Alabama                  5786.8253
# Arizona                 -3427.9246
# Arkansas                 4008.6871
# California              76381.3871
# Colorado                -6527.8579
# Connecticut              3511.4918
# Delaware                 9977.3748
# District of Columbia     1059.5893
# Florida                 -3399.3017
# Georgia                 16250.0433
# Idaho                     826.7231
# Illinois               -12607.8870
# Indiana                 18382.9363
# Iowa                     1183.8119
# Kansas                    836.4435
# Kentucky                11199.6966
# Louisiana                2196.1023
# Maine                     454.4862
# Maryland                 7031.1788
# Massachusetts            6785.5016
# Michigan                24463.1876
# Minnesota               10823.1874
# Mississippi              3172.9762
# Missouri                 6436.2105
# Montana                  1833.3285
# Nebraska                 2037.0942
# ...

# %%
plt.figure(figsize=(20,5))
sns.barplot(x=state_profit.index,y=state_profit.values)
plt.title('State wise Profit',fontsize=20)
plt.xticks(rotation=90)
plt.show()

# %%
subcat_profit=df.groupby('Sub-Category')['Profit'].sum()
subcat_profit
# Out:
# Sub-Category
# Accessories    41936.6357
# Appliances     18138.0054
# Art             6527.7870
# Binders        30221.7633
# Bookcases      -3472.5560
# Chairs         26590.1663
# Copiers        55617.8249
# Envelopes       6964.1767
# Fasteners        949.5182
# Furnishings    13059.1436
# Labels          5546.2540
# Machines        3384.7569
# Paper          34053.5693
# Phones         44515.7306
# Storage        21278.8264
# Supplies       -1189.0995
# Tables        -17725.4811
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=subcat_profit.index,y=subcat_profit.values)
plt.title('Sub-Category wise profit',fontsize=20)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# 1. Sales is directly proportional to profit.AS sales increases profit also increases.
# 2. Discount is inversely proportional to profit.Customer should be given less discount.
# 3. In 'Sub-Category' tables, bookcases and supplies, profit are less.So,this sub-category should be focused to increase profit.
# 4. Southern and Central region customers should be focused to increase the profit.
# 5. Quantity doesn't decide profit.
# 6. Furniture products should be focused to increase profit.
